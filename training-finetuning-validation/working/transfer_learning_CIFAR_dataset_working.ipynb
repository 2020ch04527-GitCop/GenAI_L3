# %%
import tensorflow as tf
from tensorflow.keras import layers, models
from tensorflow.keras.applications import MobileNetV2
from tensorflow.keras.datasets import cifar10
from tensorflow.keras.utils import to_categorical

# Load and preprocess the CIFAR-10 dataset
(x_train, y_train), (x_test, y_test) = cifar10.load_data()

# Normalize pixel values to between 0 and 1
x_train, x_test = x_train / 255.0, x_test / 255.0

# Convert class vectors to binary class matrices (one-hot encoding)
y_train = to_categorical(y_train, 10)
y_test = to_categorical(y_test, 10)

# Load the pre-trained MobileNetV2 model, excluding the top layer
base_model = MobileNetV2(weights='imagenet', include_top=False, input_shape=(32, 32, 3))

# Freeze the base model's layers so they are not updated during training
base_model.trainable = False

# Create a new model on top of the base model
model = models.Sequential([
    base_model,
    layers.GlobalAveragePooling2D(),
    layers.Dense(512, activation='relu'),
    layers.Dropout(0.5),
    layers.Dense(10, activation='softmax')  # 10 classes for CIFAR-10
])

# Compile the model
model.compile(optimizer='adam',
              loss='categorical_crossentropy',
              metrics=['accuracy'])

# Train the model
model.fit(x_train, y_train, epochs=10, batch_size=64, validation_data=(x_test, y_test))

# Fine-tune the model (optional step)
# Unfreeze some of the base model's layers and retrain the model
base_model.trainable = True

# Recompile the model with a lower learning rate
model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=1e-5),
              loss='categorical_crossentropy',
              metrics=['accuracy'])

# Continue training the model
model.fit(x_train, y_train, epochs=2, batch_size=64, validation_data=(x_test, y_test))

# Evaluate the model
test_loss, test_acc = model.evaluate(x_test, y_test)
print(f"Test accuracy: {test_acc:.4f}")
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# 170498071/170498071 ━━━━━━━━━━━━━━━━━━━━ 5s 0us/step
# /tmp/ipython-input-3839257073.py:18: UserWarning: `input_shape` is undefined or non-square, or `rows` is not in [96, 128, 160, 192, 224]. Weights for input shape (224, 224) will be loaded as the default.
#   base_model = MobileNetV2(weights='imagenet', include_top=False, input_shape=(32, 32, 3))
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/mobilenet_v2/mobilenet_v2_weights_tf_dim_ordering_tf_kernels_1.0_224_no_top.h5
# 9406464/9406464 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# Epoch 1/10
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 37s 28ms/step - accuracy: 0.2598 - loss: 2.0328 - val_accuracy: 0.3301 - val_loss: 1.8615
# Epoch 2/10
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 6s 8ms/step - accuracy: 0.3270 - loss: 1.8532 - val_accuracy: 0.3350 - val_loss: 1.8256
# Epoch 3/10
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 6s 7ms/step - accuracy: 0.3388 - loss: 1.8149 - val_accuracy: 0.3475 - val_loss: 1.8092
# Epoch 4/10
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 6s 7ms/step - accuracy: 0.3546 - loss: 1.7853 - val_accuracy: 0.3491 - val_loss: 1.7969
# Epoch 5/10
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 5s 7ms/step - accuracy: 0.3582 - loss: 1.7747 - val_accuracy: 0.3561 - val_loss: 1.7892
# Epoch 6/10
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 6s 7ms/step - accuracy: 0.3630 - loss: 1.7567 - val_accuracy: 0.3510 - val_loss: 1.7862
# Epoch 7/10
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 6s 7ms/step - accuracy: 0.3667 - loss: 1.7481 - val_accuracy: 0.3543 - val_loss: 1.7828
# Epoch 8/10
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 6s 7ms/step - accuracy: 0.3724 - loss: 1.7306 - val_accuracy: 0.3612 - val_loss: 1.7754
# Epoch 9/10
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 6s 7ms/step - accuracy: 0.3686 - loss: 1.7278 - val_accuracy: 0.3643 - val_loss: 1.7767
# Epoch 10/10
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 11s 8ms/step - accuracy: 0.3765 - loss: 1.7154 - val_accuracy: 0.3607 - val_loss: 1.7743
# Epoch 1/2
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 84s 51ms/step - accuracy: 0.1363 - loss: 26.3711 - val_accuracy: 0.1378 - val_loss: 16.9681
# Epoch 2/2
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 12s 15ms/step - accuracy: 0.1987 - loss: 7.8514 - val_accuracy: 0.1239 - val_loss: 3.2484
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 10s 5ms/step - accuracy: 0.1249 - loss: 3.2908
# Test accuracy: 0.1239

# %%
print(f"Number of test data samples: {x_test.shape[0]}")
# Out:
# Number of test data samples: 10000

# %%
print(f"Number of Train data samples: {x_train.shape[0]}")
# Out:
# Number of Train data samples: 50000

# %%
import tensorflow as tf
from tensorflow.keras import layers, models
from tensorflow.keras.applications import MobileNetV2
from tensorflow.keras.datasets import cifar10
from tensorflow.keras.utils import to_categorical

# Load and preprocess the CIFAR-10 dataset
(x_train, y_train), (x_test, y_test) = cifar10.load_data()

# Normalize pixel values to between 0 and 1
x_train, x_test = x_train / 255.0, x_test / 255.0

# Convert class vectors to binary class matrices (one-hot encoding)
y_train = to_categorical(y_train, 10)
y_test = to_categorical(y_test, 10)

# Load the pre-trained MobileNetV2 model, excluding the top layer
base_model = MobileNetV2(weights='imagenet', include_top=False, input_shape=(32, 32, 3))

# Freeze the base model's layers so they are not updated during training
base_model.trainable = False

# Create a new model on top of the base model
model = models.Sequential([
    base_model,
    layers.GlobalAveragePooling2D(),
    layers.Dense(512, activation='relu'),
    layers.Dropout(0.1),
    layers.Dense(10, activation='softmax')  # 10 classes for CIFAR-10
])

# Compile the model
model.compile(optimizer='adam',
              loss='categorical_crossentropy',
              metrics=['accuracy'])

# Train the model
model.fit(x_train, y_train, epochs=10, batch_size=64, validation_data=(x_test, y_test))

# Fine-tune the model (optional step)
# Unfreeze some of the base model's layers and retrain the model
base_model.trainable = True

# Recompile the model with a lower learning rate
model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=1e-5),
              loss='categorical_crossentropy',
              metrics=['accuracy'])

# Continue training the model
model.fit(x_train, y_train, epochs=2, batch_size=64, validation_data=(x_test, y_test))

# Evaluate the model
test_loss, test_acc = model.evaluate(x_test, y_test)
print(f"Test accuracy: {test_acc:.4f}")
# Out:
# /tmp/ipython-input-3370433972.py:18: UserWarning: `input_shape` is undefined or non-square, or `rows` is not in [96, 128, 160, 192, 224]. Weights for input shape (224, 224) will be loaded as the default.
#   base_model = MobileNetV2(weights='imagenet', include_top=False, input_shape=(32, 32, 3))
# Epoch 1/10
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 24s 20ms/step - accuracy: 0.2786 - loss: 1.9999 - val_accuracy: 0.3311 - val_loss: 1.8449
# Epoch 2/10
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 6s 8ms/step - accuracy: 0.3447 - loss: 1.8187 - val_accuracy: 0.3440 - val_loss: 1.8159
# Epoch 3/10
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 5s 7ms/step - accuracy: 0.3589 - loss: 1.7684 - val_accuracy: 0.3566 - val_loss: 1.7943
# Epoch 4/10
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 6s 8ms/step - accuracy: 0.3704 - loss: 1.7375 - val_accuracy: 0.3581 - val_loss: 1.7822
# Epoch 5/10
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 5s 7ms/step - accuracy: 0.3816 - loss: 1.7034 - val_accuracy: 0.3557 - val_loss: 1.7838
# Epoch 6/10
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 10s 7ms/step - accuracy: 0.3922 - loss: 1.6833 - val_accuracy: 0.3614 - val_loss: 1.7765
# Epoch 7/10
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 6s 7ms/step - accuracy: 0.4004 - loss: 1.6559 - val_accuracy: 0.3589 - val_loss: 1.7747
# Epoch 8/10
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 6s 7ms/step - accuracy: 0.4033 - loss: 1.6459 - val_accuracy: 0.3619 - val_loss: 1.7838
# Epoch 9/10
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 6s 8ms/step - accuracy: 0.4125 - loss: 1.6231 - val_accuracy: 0.3583 - val_loss: 1.7871
# Epoch 10/10
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 10s 7ms/step - accuracy: 0.4171 - loss: 1.6072 - val_accuracy: 0.3574 - val_loss: 1.7849
# Epoch 1/2
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 75s 46ms/step - accuracy: 0.1364 - loss: 36.8025 - val_accuracy: 0.1381 - val_loss: 31.2143
# Epoch 2/2
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 12s 15ms/step - accuracy: 0.1968 - loss: 10.3937 - val_accuracy: 0.1247 - val_loss: 4.0138
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 7ms/step - accuracy: 0.1223 - loss: 4.1087
# Test accuracy: 0.1247
